# %% [markdown]
# ### Import package

# %%
import gym
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

np.random.seed(2)
tf.set_random_seed(2)

# %matplotlib inline

# %% [markdown]
# ### Hyperparameter

# %%
MAX_EPISODE = 500 # 要跑多少個 episode
MAX_EP_STEPS = 200 # 一個 episode 要跑多少步
DISPLAY_REWARD_THRESHOLD = -60 # 如果 reward 大於這個 threshold 就 render 環境
RENDER = False # 一開始先不要 render，因為會浪費時間
GAMMA = 0.95 # reward discount factor
LR_A = 0.0001 # learning rate for actor
LR_C = 0.001 # learning rate for critic

USE_ACTION_AS_INPUT = False # whether to use action as input for critic

# %% [markdown]
# ### Environment Settings

# %%
ENV_NAME = "Pendulum-v0"
env = gym.make(ENV_NAME)
env.seed(1) # reproducible

n_obs = env.observation_space.shape[0]
is_discrete = hasattr(env.action_space, "n")

if is_discrete:
    n_action_space = env.action_space.n
else:
    n_action_space = env.action_space.shape[0]
print("The number of observation is: %s The number of action that can be taken is: %s (%s)" % \
      (n_obs, n_action_space, "discrete" if is_discrete else "continuous"))

if not is_discrete:
    action_bound = env.action_space.high
    print("Action boundary: %s ~ %s" % (env.action_space.low[0], env.action_space.high[0]))
# Out:
# The number of observation is: 3 The number of action that can be taken is: 1 (continuous)
# Action boundary: -2.0 ~ 2.0

# %% [markdown]
# <img src="img/actor_critic_pseudo.JPG",width=400,height=200>

# %% [markdown]
# ### Actor-Critic

# %%
class ActorCritic(object):
    def __init__(self, n_action_space, n_state, action_bound, sess):
        
        self.n_action_space = n_action_space
        self.n_state = n_state
        self.action_bound = action_bound
        self.sess = sess
        
        self.S = tf.placeholder(tf.float32, [1, self.n_state], 'state_input') 
        self.gt_action = tf.placeholder(tf.float32, None, 'gt_action') # groundtruth action
        self.td_error = tf.placeholder(tf.float32, None, name="td_error")  # TD_error
        
        self.R = tf.placeholder(tf.float32, name='reward')
        self.v_ = tf.placeholder(tf.float32, [1, 1], 'next_exp_v')
        
        with tf.variable_scope("Actor"):
            # create actor network
            self.action, self.normal_dist = self.create_actor(self.S)
            
            with tf.name_scope("expected_value_for_actor"):
                # actor gradient = grad[logPi(a|s) * td_error]
                self.exp_v = self.normal_dist.log_prob(self.gt_action) * self.td_error
                self.exp_v = self.exp_v - 0.01 * self.normal_dist.entropy() # Add cross entropy cost to encourage exploration
            
            with tf.name_scope("actor_train"):
                # wish to maximize Q value
                self.actor_train = tf.train.AdamOptimizer(learning_rate=LR_A).minimize(-self.exp_v) # min(-v) = max(v)
        
        with tf.variable_scope("Critic"):
            # create critic network
            self.v = self.create_critic(self.S, self.gt_action)
            
            with tf.name_scope("squared_TD_error"):
                # critic gradient = grad[r + gamma * V(s_) - V(s)]
                critic_v_target = self.R + GAMMA * self.v_
                self.critic_td_error = tf.reduce_mean(critic_v_target - self.v)
                self.loss = tf.square(self.critic_td_error)
            
            with tf.name_scope("critic_train"):
                # wish to minimize the td error
                self.critic_train = tf.train.AdamOptimizer(learning_rate=LR_C).minimize(self.loss) 
                
    def choose_action(self, s):
        s = s[np.newaxis, :]
        return self.sess.run(self.action, {self.S: s}) # return a action with continuous real number
    
    def create_actor(self, s):

        l1 = tf.layers.dense(s, units=30, activation=tf.nn.relu, name='l1')
        mu = tf.layers.dense(inputs=l1, units=1, activation=tf.nn.tanh, name='mu')
        sigma = tf.layers.dense(inputs=l1, units=1, activation=tf.nn.softplus, name='sigma')
        normal_dist = tf.distributions.Normal(tf.squeeze(mu*2), tf.squeeze(sigma + 1e-5))
        # action = tf.clip_by_value(normal_dist.sample(1), -self.action_bound[0], -self.action_bound[0], name='policy_action')
        action = tf.multiply(normal_dist.sample(1), self.action_bound, name='policy_action')
        return action, normal_dist
        
    def update_actor(self, s, a , td):
        s = s[np.newaxis, :]
        feed_dict = {self.S: s, self.gt_action: a, self.td_error: td}
        _, exp_v = self.sess.run([self.actor_train, self.exp_v], feed_dict)
        return exp_v
        
    def create_critic(self, s, a):
        
        l1 = tf.layers.dense(inputs=s, units=30, activation=tf.nn.relu, name='l1')
        if USE_ACTION_AS_INPUT:
            a = tf.reshape(a, (1, 1))
            l2 = tf.layers.dense(inputs=tf.concat([l1, a], axis=1), units=20, activation=tf.nn.relu, name="l2")
            v = tf.layers.dense(inputs=l2, units=1, activation=None, name="value")
        else:
            v = tf.layers.dense(inputs=l1, units=1, activation=None, name="value")

        return v
    
    def update_critic(self, s, r, s_, a=None):
        s, s_ = s[np.newaxis, :], s_[np.newaxis, :]

        
        if a is None:
            v_ = self.sess.run(self.v, {self.S: s_})
            td_error, _ = self.sess.run([self.critic_td_error, self.critic_train],
                                              {self.S: s, self.v_: v_, self.R: r})
        else:
            v_ = self.sess.run(self.v, {self.S: s_, self.gt_action: a})
            td_error, _ = self.sess.run([self.critic_td_error, self.critic_train],
                                              {self.S: s, self.gt_action: a, self.v_: v_, self.R: r})
            
        return td_error

# %% [markdown]
# ### Initial our Actor-Critic

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()

actor_critic = ActorCritic(n_action_space, n_obs, action_bound, sess)

sess.run(tf.global_variables_initializer())

# %% [markdown]
# ### Main training

# %%
reward_history = []
for i_episode in range(MAX_EPISODE):
    s = env.reset()
    t, ep_rs = 0, 0
    while True:
        if RENDER:
            env.render()
        a = actor_critic.choose_action(s)
        s_, r, done, info = env.step(a)
        r /= 10 # scaled reward to converge faster
        if USE_ACTION_AS_INPUT:
            td_error = actor_critic.update_critic(s, r, s_, a)
        else:
            td_error = actor_critic.update_critic(s, r, s_) # critic gradient = grad[r + gamma * V(s_) - V(s)]
        actor_critic.update_actor(s, a, td_error) # actor gradient = grad[logPi(a|s) * td_error]

        s = s_
        t += 1
        ep_rs += r
        
        if t > MAX_EP_STEPS:
            reward_history.append(ep_rs)
            if 'running_reward' not in globals():
                running_reward = ep_rs
            else:
                running_reward = running_reward * 0.9 + ep_rs * 0.1 # 希望是穩定的 reward
            
            if running_reward > DISPLAY_REWARD_THRESHOLD: RENDER = True  # rendering
            print("episode:", i_episode, "  reward:", int(running_reward))
            break
# Out:
# episode: 0   reward: -106
# episode: 1   reward: -107
# episode: 2   reward: -113
# episode: 3   reward: -115
# episode: 4   reward: -120
# episode: 5   reward: -122
# episode: 6   reward: -124
# episode: 7   reward: -126
# episode: 8   reward: -129
# episode: 9   reward: -131
# episode: 10   reward: -134
# episode: 11   reward: -137
# episode: 12   reward: -138
# episode: 13   reward: -138
# episode: 14   reward: -141
# episode: 15   reward: -141
# episode: 16   reward: -139
# episode: 17   reward: -141
# episode: 18   reward: -143
# episode: 19   reward: -141
# episode: 20   reward: -142
# episode: 21   reward: -138
# episode: 22   reward: -140
# episode: 23   reward: -143
# episode: 24   reward: -140
# episode: 25   reward: -141
# episode: 26   reward: -140
# episode: 27   reward: -141
# episode: 28   reward: -138
# episode: 29   reward: -140
# episode: 30   reward: -142
# episode: 31   reward: -138
# episode: 32   reward: -139
# episode: 33   reward: -141
# episode: 34   reward: -138
# episode: 35   reward: -139
# episode: 36   reward: -140
# episode: 37   reward: -140
# episode: 38   reward: -141
# episode: 39   reward: -140
# episode: 40   reward: -142
# episode: 41   reward: -142
# episode: 42   reward: -139
# episode: 43   reward: -138
# episode: 44   reward: -135
# episode: 45   reward: -138
# episode: 46   reward: -133
# episode: 47   reward: -133
# episode: 48   reward: -129
# episode: 49   reward: -128
# episode: 50   reward: -130
# episode: 51   reward: -131
# episode: 52   reward: -132
# episode: 53   reward: -133
# episode: 54   reward: -136
# episode: 55   reward: -135
# episode: 56   reward: -134
# episode: 57   reward: -134
# episode: 58   reward: -132
# episode: 59   reward: -131
# episode: 60   reward: -130
# episode: 61   reward: -128
# episode: 62   reward: -126
# episode: 63   reward: -123
# episode: 64   reward: -119
# episode: 65   reward: -118
# episode: 66   reward: -119
# episode: 67   reward: -121
# episode: 68   reward: -120
# episode: 69   reward: -120
# episode: 70   reward: -119
# episode: 71   reward: -119
# episode: 72   reward: -119
# episode: 73   reward: -115
# episode: 74   reward: -114
# episode: 75   reward: -112
# episode: 76   reward: -111
# episode: 77   reward: -109
# episode: 78   reward: -110
# episode: 79   reward: -106
# episode: 80   reward: -108
# episode: 81   reward: -109
# episode: 82   reward: -111
# episode: 83   reward: -112
# episode: 84   reward: -109
# episode: 85   reward: -110
# episode: 86   reward: -106
# episode: 87   reward: -103
# episode: 88   reward: -102
# episode: 89   reward: -98
# episode: 90   reward: -99
# episode: 91   reward: -99
# episode: 92   reward: -98
# episode: 93   reward: -97
# episode: 94   reward: -98
# episode: 95   reward: -97
# episode: 96   reward: -98
# episode: 97   reward: -96
# episode: 98   reward: -95
# episode: 99   reward: -97
# episode: 100   reward: -96
# episode: 101   reward: -97
# episode: 102   reward: -100
# episode: 103   reward: -99
# episode: 104   reward: -98
# episode: 105   reward: -99
# episode: 106   reward: -98
# episode: 107   reward: -97
# episode: 108   reward: -98
# episode: 109   reward: -94
# episode: 110   reward: -94
# episode: 111   reward: -92
# episode: 112   reward: -94
# episode: 113   reward: -95
# episode: 114   reward: -95
# episode: 115   reward: -96
# episode: 116   reward: -97
# episode: 117   reward: -96
# episode: 118   reward: -93
# episode: 119   reward: -94
# episode: 120   reward: -94
# episode: 121   reward: -93
# episode: 122   reward: -93
# episode: 123   reward: -92
# episode: 124   reward: -90
# episode: 125   reward: -88
# episode: 126   reward: -87
# episode: 127   reward: -85
# episode: 128   reward: -83
# episode: 129   reward: -81
# episode: 130   reward: -79
# episode: 131   reward: -80
# episode: 132   reward: -80
# episode: 133   reward: -78
# episode: 134   reward: -81
# episode: 135   reward: -78
# episode: 136   reward: -79
# episode: 137   reward: -79
# episode: 138   reward: -79
# episode: 139   reward: -78
# episode: 140   reward: -76
# episode: 141   reward: -78
# episode: 142   reward: -79
# episode: 143   reward: -78
# episode: 144   reward: -79
# episode: 145   reward: -80
# episode: 146   reward: -81
# episode: 147   reward: -85
# episode: 148   reward: -85
# episode: 149   reward: -84
# episode: 150   reward: -85
# episode: 151   reward: -86
# episode: 152   reward: -86
# episode: 153   reward: -82
# episode: 154   reward: -84
# episode: 155   reward: -85
# episode: 156   reward: -88
# episode: 157   reward: -88
# episode: 158   reward: -86
# episode: 159   reward: -87
# episode: 160   reward: -83
# episode: 161   reward: -84
# episode: 162   reward: -81
# episode: 163   reward: -79
# episode: 164   reward: -78
# episode: 165   reward: -80
# episode: 166   reward: -81
# episode: 167   reward: -81
# episode: 168   reward: -83
# episode: 169   reward: -81
# episode: 170   reward: -80
# episode: 171   reward: -80
# episode: 172   reward: -78
# episode: 173   reward: -76
# episode: 174   reward: -78
# episode: 175   reward: -77
# episode: 176   reward: -77
# episode: 177   reward: -76
# episode: 178   reward: -76
# episode: 179   reward: -76
# episode: 180   reward: -75
# episode: 181   reward: -77
# episode: 182   reward: -77
# episode: 183   reward: -78
# episode: 184   reward: -78
# episode: 185   reward: -77
# episode: 186   reward: -77
# episode: 187   reward: -75
# episode: 188   reward: -75
# episode: 189   reward: -75
# episode: 190   reward: -76
# episode: 191   reward: -77
# episode: 192   reward: -76
# episode: 193   reward: -75
# episode: 194   reward: -76
# episode: 195   reward: -77
# episode: 196   reward: -75
# episode: 197   reward: -73
# episode: 198   reward: -73
# episode: 199   reward: -74
# episode: 200   reward: -73
# episode: 201   reward: -71
# episode: 202   reward: -70
# episode: 203   reward: -71
# episode: 204   reward: -67
# episode: 205   reward: -68
# episode: 206   reward: -70
# episode: 207   reward: -72
# episode: 208   reward: -75
# episode: 209   reward: -74
# episode: 210   reward: -70
# episode: 211   reward: -68
# episode: 212   reward: -70
# episode: 213   reward: -68
# episode: 214   reward: -69
# episode: 215   reward: -67
# episode: 216   reward: -68
# episode: 217   reward: -65
# episode: 218   reward: -67
# episode: 219   reward: -70
# episode: 220   reward: -73
# episode: 221   reward: -72
# episode: 222   reward: -69
# episode: 223   reward: -66
# episode: 224   reward: -66
# episode: 225   reward: -62
# episode: 226   reward: -61
# episode: 227   reward: -59
# episode: 228   reward: -59
# episode: 229   reward: -61
# episode: 230   reward: -60
# episode: 231   reward: -63
# episode: 232   reward: -62
# episode: 233   reward: -61
# episode: 234   reward: -63
# episode: 235   reward: -63
# episode: 236   reward: -66
# episode: 237   reward: -64
# episode: 238   reward: -66
# episode: 239   reward: -65
# episode: 240   reward: -63
# episode: 241   reward: -64
# episode: 242   reward: -65
# episode: 243   reward: -63
# episode: 244   reward: -59
# episode: 245   reward: -58
# episode: 246   reward: -55
# episode: 247   reward: -57
# episode: 248   reward: -55
# episode: 249   reward: -55
# episode: 250   reward: -55
# episode: 251   reward: -60
# episode: 252   reward: -62
# episode: 253   reward: -63
# episode: 254   reward: -66
# episode: 255   reward: -62
# episode: 256   reward: -63
# episode: 257   reward: -69
# episode: 258   reward: -66
# episode: 259   reward: -67
# episode: 260   reward: -69
# episode: 261   reward: -70
# episode: 262   reward: -65
# episode: 263   reward: -66
# episode: 264   reward: -67
# episode: 265   reward: -63
# episode: 266   reward: -66
# episode: 267   reward: -67
# episode: 268   reward: -68
# episode: 269   reward: -65
# episode: 270   reward: -64
# episode: 271   reward: -64
# episode: 272   reward: -62
# episode: 273   reward: -61
# episode: 274   reward: -60
# episode: 275   reward: -59
# episode: 276   reward: -61
# episode: 277   reward: -62
# episode: 278   reward: -57
# episode: 279   reward: -58
# episode: 280   reward: -61
# episode: 281   reward: -60
# episode: 282   reward: -60
# episode: 283   reward: -61
# episode: 284   reward: -62
# episode: 285   reward: -60
# episode: 286   reward: -61
# episode: 287   reward: -62
# episode: 288   reward: -60
# episode: 289   reward: -58
# episode: 290   reward: -57
# episode: 291   reward: -54
# episode: 292   reward: -55
# episode: 293   reward: -54
# episode: 294   reward: -52
# episode: 295   reward: -56
# episode: 296   reward: -59
# episode: 297   reward: -56
# episode: 298   reward: -50
# episode: 299   reward: -51
# episode: 300   reward: -48
# episode: 301   reward: -46
# episode: 302   reward: -53
# episode: 303   reward: -53
# episode: 304   reward: -55
# episode: 305   reward: -53
# episode: 306   reward: -48
# episode: 307   reward: -46
# episode: 308   reward: -51
# episode: 309   reward: -53
# episode: 310   reward: -51
# episode: 311   reward: -49
# episode: 312   reward: -51
# episode: 313   reward: -51
# episode: 314   reward: -51
# episode: 315   reward: -54
# episode: 316   reward: -51
# episode: 317   reward: -47
# episode: 318   reward: -52
# episode: 319   reward: -48
# episode: 320   reward: -45
# episode: 321   reward: -45
# episode: 322   reward: -43
# episode: 323   reward: -43
# episode: 324   reward: -41
# episode: 325   reward: -41
# episode: 326   reward: -39
# episode: 327   reward: -35
# episode: 328   reward: -34
# episode: 329   reward: -33
# episode: 330   reward: -33
# episode: 331   reward: -33
# episode: 332   reward: -31
# episode: 333   reward: -29
# episode: 334   reward: -32
# episode: 335   reward: -33
# episode: 336   reward: -37
# episode: 337   reward: -34
# episode: 338   reward: -37
# episode: 339   reward: -37
# episode: 340   reward: -44
# episode: 341   reward: -42
# episode: 342   reward: -38
# episode: 343   reward: -37
# episode: 344   reward: -41
# episode: 345   reward: -46
# episode: 346   reward: -46
# episode: 347   reward: -47
# episode: 348   reward: -45
# episode: 349   reward: -46
# episode: 350   reward: -51
# episode: 351   reward: -49
# episode: 352   reward: -44
# episode: 353   reward: -47
# episode: 354   reward: -43
# episode: 355   reward: -45
# episode: 356   reward: -44
# episode: 357   reward: -41
# episode: 358   reward: -38
# episode: 359   reward: -36
# episode: 360   reward: -38
# episode: 361   reward: -35
# episode: 362   reward: -39
# episode: 363   reward: -37
# episode: 364   reward: -42
# episode: 365   reward: -50
# episode: 366   reward: -46
# episode: 367   reward: -46
# episode: 368   reward: -41
# episode: 369   reward: -40
# episode: 370   reward: -37
# episode: 371   reward: -33
# episode: 372   reward: -35
# episode: 373   reward: -34
# episode: 374   reward: -31
# episode: 375   reward: -32
# episode: 376   reward: -30
# episode: 377   reward: -29
# episode: 378   reward: -33
# episode: 379   reward: -35
# episode: 380   reward: -35
# episode: 381   reward: -37
# episode: 382   reward: -37
# episode: 383   reward: -35
# episode: 384   reward: -31
# episode: 385   reward: -32
# episode: 386   reward: -30
# episode: 387   reward: -34
# episode: 388   reward: -36
# episode: 389   reward: -37
# episode: 390   reward: -42
# episode: 391   reward: -43
# episode: 392   reward: -46
# episode: 393   reward: -48
# episode: 394   reward: -48
# episode: 395   reward: -46
# episode: 396   reward: -46
# episode: 397   reward: -44
# episode: 398   reward: -39
# episode: 399   reward: -37
# episode: 400   reward: -34
# episode: 401   reward: -32
# episode: 402   reward: -30
# episode: 403   reward: -27
# episode: 404   reward: -28
# episode: 405   reward: -35
# episode: 406   reward: -36
# episode: 407   reward: -42
# episode: 408   reward: -39
# episode: 409   reward: -37
# episode: 410   reward: -38
# episode: 411   reward: -37
# episode: 412   reward: -38
# episode: 413   reward: -37
# episode: 414   reward: -35
# episode: 415   reward: -38
# episode: 416   reward: -34
# episode: 417   reward: -36
# episode: 418   reward: -34
# episode: 419   reward: -33
# episode: 420   reward: -38
# episode: 421   reward: -35
# episode: 422   reward: -34
# episode: 423   reward: -36
# episode: 424   reward: -39
# episode: 425   reward: -43
# episode: 426   reward: -42
# episode: 427   reward: -44
# episode: 428   reward: -40
# episode: 429   reward: -38
# episode: 430   reward: -34
# episode: 431   reward: -34
# episode: 432   reward: -33
# episode: 433   reward: -31
# episode: 434   reward: -31
# episode: 435   reward: -35
# episode: 436   reward: -43
# episode: 437   reward: -41
# episode: 438   reward: -39
# episode: 439   reward: -37
# episode: 440   reward: -38
# episode: 441   reward: -41
# episode: 442   reward: -38
# episode: 443   reward: -34
# episode: 444   reward: -31
# episode: 445   reward: -33
# episode: 446   reward: -30
# episode: 447   reward: -32
# episode: 448   reward: -29
# episode: 449   reward: -33
# episode: 450   reward: -29
# episode: 451   reward: -28
# episode: 452   reward: -28
# episode: 453   reward: -26
# episode: 454   reward: -26
# episode: 455   reward: -26
# episode: 456   reward: -26
# episode: 457   reward: -23
# episode: 458   reward: -22
# episode: 459   reward: -25
# episode: 460   reward: -25
# episode: 461   reward: -26
# episode: 462   reward: -27
# episode: 463   reward: -27
# episode: 464   reward: -27
# episode: 465   reward: -27
# episode: 466   reward: -25
# episode: 467   reward: -27
# episode: 468   reward: -26
# episode: 469   reward: -26
# episode: 470   reward: -26
# episode: 471   reward: -25
# episode: 472   reward: -25
# episode: 473   reward: -24
# episode: 474   reward: -21
# episode: 475   reward: -24
# episode: 476   reward: -24
# episode: 477   reward: -26
# episode: 478   reward: -26
# episode: 479   reward: -27
# episode: 480   reward: -34
# episode: 481   reward: -32
# episode: 482   reward: -31
# episode: 483   reward: -32
# episode: 484   reward: -30
# episode: 485   reward: -29
# episode: 486   reward: -29
# episode: 487   reward: -26
# episode: 488   reward: -26
# episode: 489   reward: -25
# episode: 490   reward: -28
# episode: 491   reward: -28
# episode: 492   reward: -28
# episode: 493   reward: -30
# episode: 494   reward: -29
# episode: 495   reward: -26
# episode: 496   reward: -28
# episode: 497   reward: -27
# episode: 498   reward: -30
# episode: 499   reward: -30

# %%
plt.plot(reward_history)

# %%
# Add ops to save and restore all the variables.
saver = tf.train.Saver()
# Save the variables to disk.
save_path = saver.save(sess, "checkpoint/ac_v1.ckpt")

# %% [markdown]
# ### Use checkpoint
# 這裡有幫大家跑好 `USE_ACTION_AS_INPUT = False` 的 model，有興趣的話可以 restore ac.ckpt 這個 checkpoint 來玩 pendulum。

# %%
saver.restore(sess, "checkpoint/ac_v1.ckpt")
s = env.reset()
i_step = 0
while True:
    env.render()
    a = actor_critic.choose_action(s)
    s_, r, done, info = env.step(a)
    s = s_
    i_step += 1
    if i_step > 300:
        break
# Out:
# INFO:tensorflow:Restoring parameters from checkpoint/ac_v1.ckpt
