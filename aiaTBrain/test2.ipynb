# %%
import pandas as pd
import numpy as np
import datetime

log = []
for i in range(301,332):
    log.append(('query_log/0{}.csv'.format(i)))
for i in range(401,431):
    log.append(('query_log/0{}.csv'.format(i)))
for i in range(501,532):
    log.append(('query_log/0{}.csv'.format(i)))
    
df_log0301 = pd.DataFrame(pd.read_csv(log[0],header=None))
df_log0301.columns = ['FileID', 'CustomerID', 'QueryTS', 'ProductID']
df_log0301['Dtime'] = pd.to_datetime(df_log0301['QueryTS'], unit='s')

# %%
df_log = pd.DataFrame()
for i in range(len(log)):
    print(log[i])
    df_log = df_log.append(pd.DataFrame(pd.read_csv(log[i],header=None)))
df_log.columns = ['FileID', 'CustomerID', 'QueryTS', 'ProductID']
df_log = df_log.reset_index(drop=True)
# Out:
# query_log/0301.csv
# query_log/0302.csv
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# query_log/0303.csv
# query_log/0304.csv
# query_log/0305.csv
# query_log/0306.csv
# query_log/0307.csv
# query_log/0308.csv
# query_log/0309.csv
# query_log/0310.csv
# query_log/0311.csv
# query_log/0312.csv
# query_log/0313.csv
# query_log/0314.csv
# query_log/0315.csv
# query_log/0316.csv
# query_log/0317.csv
# query_log/0318.csv
# query_log/0319.csv
# query_log/0320.csv
# query_log/0321.csv
# query_log/0322.csv
# query_log/0323.csv
# query_log/0324.csv
# query_log/0325.csv
# query_log/0326.csv
# query_log/0327.csv
# query_log/0328.csv
# query_log/0329.csv
# query_log/0330.csv
# query_log/0331.csv
# query_log/0401.csv
# query_log/0402.csv
# query_log/0403.csv
# query_log/0404.csv
# ...

# %%
df_log['Dtime'] = pd.to_datetime(df_log['QueryTS'], unit='s')
df_log['Label'] = 3

# %%
tesr = pd.read_csv('total_log.csv')
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(pd.unique(df_log['CustomerID']))
# Out:
# 5539312

# %%
df_train = pd.DataFrame(pd.read_csv('training-set.csv',header=None))
df_train.columns = ['FileID','Label']

# %%
tr = set(pd.unique(df_train['FileID']))
len(tr)
# Out:
# 52518

# %%
dic = df_train.set_index('FileID').to_dict()

dic = dic['Label']

# %%
df_log04 = pd.DataFrame()
for i in range(31,61):
    print(log[i])
    df_log04 = df_log04.append(pd.DataFrame(pd.read_csv(log[i],header=None)))
df_log04.columns = ['FileID', 'CustomerID', 'QueryTS', 'ProductID']
df_log04 = df_log04.reset_index(drop=True)
# Out:
# query_log/0401.csv
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# query_log/0402.csv
# query_log/0403.csv
# query_log/0404.csv
# query_log/0405.csv
# query_log/0406.csv
# query_log/0407.csv
# query_log/0408.csv
# query_log/0409.csv
# query_log/0410.csv
# query_log/0411.csv
# query_log/0412.csv
# query_log/0413.csv
# query_log/0414.csv
# query_log/0415.csv
# query_log/0416.csv
# query_log/0417.csv
# query_log/0418.csv
# query_log/0419.csv
# query_log/0420.csv
# query_log/0421.csv
# query_log/0422.csv
# query_log/0423.csv
# query_log/0424.csv
# query_log/0425.csv
# query_log/0426.csv
# query_log/0427.csv
# query_log/0428.csv
# query_log/0429.csv
# query_log/0430.csv

# %%
df_log04['Dtime'] = pd.to_datetime(df_log04['QueryTS'], unit='s')

# %%
li = list(df_train['FileID'])

# %%
df = pd.DataFrame()
for i in range(len(li)):
    print(i)
    df = df.append(df_log04[df_log04['FileID'] == li[i]])

# %%
df_log04
# Out:
#                                     FileID                        CustomerID  \
# 0         7604044cfa8699fb030fd36478fb5b5f  a005386e15c5c16df721848a1f0559b4
# 1         9fd3347fbb5bead2f129dd1822156c8b  9f53bc347227bfcbdb9bd3acf5b784bb
# 2         dec43d1faf93e3ff3391b609c9ed5c64  b22b3b8b043b3abb1b10e26f89d8987e
# 3         175766b0cad7ff4f064a520cde9d1cf3  5ffd50fd15bc595593a5d3b9f88888b5
# 4         34e97de2b783993451a6bbad86761859  313ec63386c9aae63295737e0952ced7
# 5         0007819a84e047a78fbbd620557104ad  217e1bc883a60f9f0ee8b79697b73cca
# 6         a00a4fa61431b9465904b5c6a8ad7346  ed59536d35a3cd2b9834d41afe90853d
# 7         d03dc8362e20c68a78ac1130484333f2  ee733866d683e2bd219e329690d1d3df
# 8         c573cfc334ab15a17c73ec06eed81bb3  ee733866d683e2bd219e329690d1d3df
# 9         25fa00e6577b2f9a4aa7075c785516f4  ee733866d683e2bd219e329690d1d3df
# 10        df96db35de5fb43a2cdfdbd7b4291163  ee733866d683e2bd219e329690d1d3df
# ...

# %%
df_train04 = df_log04[df_log04.FileID.isin(li)]

# %%
df_train04
# Out:
#                                     FileID                        CustomerID  \
# 0         7604044cfa8699fb030fd36478fb5b5f  a005386e15c5c16df721848a1f0559b4
# 1         9fd3347fbb5bead2f129dd1822156c8b  9f53bc347227bfcbdb9bd3acf5b784bb
# 2         dec43d1faf93e3ff3391b609c9ed5c64  b22b3b8b043b3abb1b10e26f89d8987e
# 3         175766b0cad7ff4f064a520cde9d1cf3  5ffd50fd15bc595593a5d3b9f88888b5
# 4         34e97de2b783993451a6bbad86761859  313ec63386c9aae63295737e0952ced7
# 5         0007819a84e047a78fbbd620557104ad  217e1bc883a60f9f0ee8b79697b73cca
# 6         a00a4fa61431b9465904b5c6a8ad7346  ed59536d35a3cd2b9834d41afe90853d
# 7         d03dc8362e20c68a78ac1130484333f2  ee733866d683e2bd219e329690d1d3df
# 8         c573cfc334ab15a17c73ec06eed81bb3  ee733866d683e2bd219e329690d1d3df
# 9         25fa00e6577b2f9a4aa7075c785516f4  ee733866d683e2bd219e329690d1d3df
# 10        df96db35de5fb43a2cdfdbd7b4291163  ee733866d683e2bd219e329690d1d3df
# ...
