# %%
import test_yolo
# Out:
# Using TensorFlow backend.

# %%
args = test_yolo.parser.parse_known_args()[0]
args.weights_path= 'trained_stage_2_best.h5'
args.test_path = '/data/examples/yolo_data/test_img'
args.output_path = 'test_img/out'
args.classes_path = '/data/examples/yolo_data/model_data/pascal_classes.txt'
t = test_yolo._main(args)
# Out:
# trained_stage_2_best.h5 model, anchors, and classes loaded.

# %%
t
# Out:
# [(<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=352x448 at 0x7F0684442AC8>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F06843E70F0>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=773x512 at 0x7F06843E71D0>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F06843E7320>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x7F06843E72E8>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=773x512 at 0x7F0684442FD0>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x576 at 0x7F06843E75F8>),
#  ([],
#   [],
#   [],
#   [],
#   [['person 0.63', (181, 73, 295, 353)]],
#   [['sheep 0.39', (387, 199, 618, 336)]],
#   [])]

# %%
i = 4
print(t[1][i])
t[0][i]
# Out:
# [['person 0.63', (181, 73, 295, 353)]]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x7F06843E72E8>
